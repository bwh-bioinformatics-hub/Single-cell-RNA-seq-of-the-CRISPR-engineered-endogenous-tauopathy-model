# %%
import pickle, numpy as np, pandas as pd, networkx as nx, warnings
warnings.filterwarnings('ignore')

import matplotlib, matplotlib.pyplot as plt
import sys
matplotlib.rcParams['font.sans-serif'] = "Arial"
matplotlib.rcParams['font.family'] = "Arial"

import seaborn as sns, OmicsIntegrator as oi

# %%
infile="/mnt/data0/projects/biohub/hassan2022/output/omicsintegrator/output/Central_Body/Central_Body_randomization_results.pkl"
parameter_set="W_6.00_B_10.00_G_6.00"
outname="{}.augmented_forest.graphml"
outdir="/mnt/data0/projects/biohub/hassan2022/output/omicsintegrator/output/Optic_Lobe"

# %%
    with open(infile, "rb") as f: 
        results=pickle.load(f)

# %%
results
# Out:
# {'W_1.00_B_2.00_G_2.00': {'forest': <networkx.classes.graph.Graph at 0x7f28f63ef4e0>,
#   'augmented_forest': <networkx.classes.graph.Graph at 0x7f28f5d15c18>},
#  'W_1.00_B_2.00_G_5.00': {'forest': <networkx.classes.graph.Graph at 0x7f28f469f9e8>,
#   'augmented_forest': <networkx.classes.graph.Graph at 0x7f28f3e0cef0>},
#  'W_1.00_B_2.00_G_6.00': {'forest': <networkx.classes.graph.Graph at 0x7f28f35f9b00>,
#   'augmented_forest': <networkx.classes.graph.Graph at 0x7f28f3260e48>},
#  'W_1.00_B_5.00_G_2.00': {'forest': <networkx.classes.graph.Graph at 0x7f28f2ad7b00>,
#   'augmented_forest': <networkx.classes.graph.Graph at 0x7f28f1b44e48>},
#  'W_1.00_B_5.00_G_5.00': {'forest': <networkx.classes.graph.Graph at 0x7f28efe84c88>,
#   'augmented_forest': <networkx.classes.graph.Graph at 0x7f28ef516240>},
#  'W_1.00_B_5.00_G_6.00': {'forest': <networkx.classes.graph.Graph at 0x7f28ed704f60>,
#   'augmented_forest': <networkx.classes.graph.Graph at 0x7f28ecd082e8>},
# ...

# %%
results[parameter_set]
# Out:
# {'forest': <networkx.classes.graph.Graph at 0x7f28ca295c50>,
#  'augmented_forest': <networkx.classes.graph.Graph at 0x7f28c9bbc320>}

# %%
for node in results[parameter_set]["augmented_forest"].node:
    for attrib in results[parameter_set]["augmented_forest"].node[node]:
        print(results[parameter_set]["augmented_forest"].node[node][attrib])
# Out:
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 39
# 3.4286955653681464e-05
# 0
# 0.0
# 0.03
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 200
# 0.0002255215242205513
# 1
# 0.0
# 0.04
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 4
# 0.0
# 2
# 0.0
# 0.01
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 8
# 2.7165160859772176e-05
# 3
# 0.0
# 0.05
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 39
# 1.0916723605211446e-05
# 2
# 0.0
# 0.04
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 5
# 0.0
# 2
# 0.0
# 0.05
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 2
# 0.0
# 4
# 0.0
# 0.02
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 7
# 0.0009573175043578123
# 5
# 1.0
# 0.04
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 201
# 0.006170175137259333
# 2
# 0.0
# 0.02
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# 39
# 1.0916723605211446e-05
# 2
# 0.0
# 0.03
# 0.0
# nan
# nan
# nan
# nan
# nan
# False
# protein
# ...

# %%
results[parameter_set]["augmented_forest"]
# Out:
# NodeView(('papi', 'RpS15Ab', 'CG1416', 'CG14516', 'CG3829', 'upd3', 'Nbr', 'homer', 'Caf1', 'CG12789', 'Lsm10', 'bl', 'CG34057', 'Sap-r', 'dhd', 'Ref1', 'Eaf', 'rho-7', 'RpS17', 'CG3437', 'SK', 'Tep2', 'Rel', 'Nf-YA', 'fz4', 'NimA', 'shf', 'CG8132', 'Cbs', 'CG7429', 'Fas2', 'stv', 'slx1', 'CG43921', 'GstT2', 'CG31202', 'ea', 'Vha16-5', 'AGBE', 'CG17002', 'CG10960', 'Sod', 'CG16892', 'CG13526', 'Prx3', 'Dark', 'CG1665', 'Vps36', 'atms', 'cni', 'mRpS5', 'CG14688', 'CG33098', 'RpS10a', 'dj', 'CG32006', 'CG6950', 'Tsf3', 'CG8235', 'CG8258', 'CG3014', 'Cap-D3', 'Spn28Dc', 'CG11858', 'milt', 'hipk', 'kuz', 'Prpk', 'Ir64a', 'Hex-t2', 'Elf', 'CG10226', 'RacGAP84C', 'spz', 'pgc', 'CG9667', 'eRF1', 'Pex3', 'CstF-50', 'CG31546', 'CG14671', 'nrv2', 'Bap60', 'htt', 'toy', 'RpS15', 'cutlet', 'Pdi', 'CG42672', 'CG3822', 'Cpsf100', 'CG8004', 'CG9008', 'CG4168', 'CG6509', 'BBS8', 'Tis11', 'S-Lap7', 'CG5800', 'CG33156', 'fzo', 'CG11089', 'CG7560', 'Slimp', 'Sytalpha', 'LSm3', 'r', '5PtaseI', 'osk', 'C
# ...
